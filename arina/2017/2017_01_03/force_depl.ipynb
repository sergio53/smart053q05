# %%
# !chmod 777 ./filter01.py

# %%
# !./filter01.py < force_depl > force_depl_02
# !cat force_depl_02
# Out:
# 0.0 0.0
# 0.04 2.80957063474
# 0.08 5.35986642406
# 0.12 7.89321097485
# 0.16 10.555244743
# 0.2 12.8980247897
# 0.24 14.7162511162
# 0.28 16.0148505389
# 0.32 16.9668550241
# 0.36 18.1422493206
# 0.4 19.0103277517
# 0.44 19.6007542162
# 0.48 19.984608501
# 0.52 20.263227414
# 0.56 20.2687730207
# 0.6 20.4349304749
# 0.64 20.5782745645
# 0.68 20.7060202066
# 0.72 20.8213435603
# 0.76 20.9267491796
# 0.8 20.7862805476
# 0.84 20.8764402423
# 0.88 20.9583668908
# 0.92 21.0358758462
# 0.96 21.1097085097
# 1.0 21.2057428091
# 1.04 21.2351337656
# 1.08 21.3687879764
# 1.12 21.4676219972
# 1.16 21.5579012248
# 1.2 21.680331047
# 1.24 21.8004643823
# 1.248 21.9242929112

# %%
# !./filter01.py force_depl
# !cat force_depl.filtered

# %%
# !chmod 777 ./DeriveCreep.py
# !./DeriveCreep.py Creep_600C_115MPa.txt
# Out:
# #t eps sig depsdt
# 298.8 0.001127396 115.0 3.7730789826e-06
# 900.0 0.001578354 115.0 7.50096473719e-07
# 1800.0 0.002254791 115.0 7.51596666667e-07
# 2700.0 0.00270575 115.0 5.01065555556e-07
# 3600.0 0.002931229 115.0 2.50532222222e-07
# 7200.0 0.004509583 115.0 4.38431666667e-07
# 10800.0 0.005636979 115.0 3.13165555556e-07
# 14400.0 0.006764374 115.0 3.13165277778e-07
# 18000.0 0.00789177 115.0 3.13165555556e-07
# 21600.0 0.008342728 115.0 1.25266111111e-07
# 25200.0 0.009695603 115.0 3.75798611111e-07
# 28800.0 0.010146561 115.0 1.25266111111e-07
# 32400.0 0.011273957 115.0 3.13165555556e-07
# 36000.0 0.012401353 115.0 3.13165555556e-07
# 39600.0 0.012852311 115.0 1.25266111111e-07
# 43200.0 0.014656144 115.0 5.01064722222e-07
# 46800.0 0.015107103 115.0 1.25266388889e-07
# 50400.0 0.01578354 115.0 1.87899166667e-07
# 54000.0 0.016910936 115.0 3.13165555556e-07
# 57600.0 0.017361894 115.0 1.25266111111e-07
# 61200.0 0.018714769 115.0 3.75798611111e-07
# ...
