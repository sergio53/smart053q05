# %%
# %matplotlib inline

# %%
# !ls my_fluage_acq.py
# Out:
# my_fluage_acq.py

# %%
from my_fluage_acq import *
dump = [None,None]

# %% [markdown]
# ## 1. reading data file :

# %% [markdown]
# ### 1(a). from SERVER host :

# %%
reader('2267.acquisition', True,dump)
# Out:
# 5672

# %% [markdown]
# ### 1(b). uploading from CLIENT host :

# %%
reader(None, True,dump)

# %% [markdown]
# ## 2. plots generation :

# %%
levol,irupt = dump
irupt
# Out:
# 5672

# %% [markdown]
# ### 2.1. Mise en temperature :

# %%
compute_mt_images('',levol[0])
# Out:
# /root/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'Arial'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### 2.2. Mise en charge :

# %%
fff = compute_mc_images('',levol[1])
for _ in fff: pass

# %% [markdown]
# ### 2.3. Fluage :

# %%
fff = compute_fl_images('',levol[2], levol[3], irupt)
for _ in fff: pass
