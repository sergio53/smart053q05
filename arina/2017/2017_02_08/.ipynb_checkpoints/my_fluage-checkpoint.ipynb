# %%
# %matplotlib inline

# %%
# !ls my_fluage_acq.py
# Out:
# my_fluage_acq.py

# %%
import my_fluage_acq as myflu
dump = [None,None]

# %% [markdown]
# ## 1. reading data file :

# %% [markdown]
# ### 1(a). from SERVER host :

# %%
myflu.reader('2267.acquisition', True,dump)
# Out:
# 5672

# %% [markdown]
# ### 1(b). uploading from CLIENT host :

# %%
myflu.reader(None, True,dump)
# Out:
# File '2267.acquisition' uploaded successfully!

# %% [markdown]
# ## 2. plots generation :

# %%
levol,irupt = dump
irupt
# Out:
# 5672

# %% [markdown]
# ### 2.1. Mise en temperature :

# %%
myflu.compute_mt_images('',levol[0])

# %% [markdown]
# ### 2.2. Mise en charge :

# %%
fff = myflu.compute_mc_images('',levol[1])
for _ in fff: pass

# %% [markdown]
# ### 2.3. Fluage :

# %%
fff = myflu.compute_fl_images('',levol[2], levol[3], irupt)
for _ in fff: pass
