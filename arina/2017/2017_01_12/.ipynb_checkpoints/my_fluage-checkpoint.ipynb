# %%
# %matplotlib inline

# %%
# !ls my_fluage_acq.py
# Out:
# my_fluage_acq.py

# %%
import my_fluage_acq as myflu
dump = [None,None]

# %% [markdown]
# ## 1(a). reading data file  (from SERVER host) :

# %%
myflu.reader('/notebooks/arinas/12_01_2017/2266.acquisition', True,dump)
# Out:
# 2372

# %% [markdown]
# ## 1(b). uploading data file (from CLIENT host) :

# %%
myflu.reader(None, True,dump)

# %% [markdown]
# ## 2. plots generation :

# %%
levol,irupt = dump
irupt
# Out:
# 2372

# %% [markdown]
# ### 2.1. Mise en temperature :

# %%
myflu.compute_mt_images('',levol[0])

# %% [markdown]
# ### 2.2. Mise en charge :

# %%
fff = myflu.compute_mc_images('',levol[1])
for _ in fff: pass

# %% [markdown]
# ### 2.3. Fluage :

# %%
fff = myflu.compute_fl_images('',levol[2], levol[3], irupt)

# %%
fff.next()

# %%
fff.next()

# %%
fff.next()

# %%
fff.next();
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/matplotlib/scale.py:93: RuntimeWarning: invalid value encountered in less_equal
#   mask = a <= 0.0

# %%
import sys
sys.path
# Out:
# ['',
#  '/opt/anaconda2/lib/python27.zip',
#  '/opt/anaconda2/lib/python2.7',
#  '/opt/anaconda2/lib/python2.7/plat-linux2',
#  '/opt/anaconda2/lib/python2.7/lib-tk',
#  '/opt/anaconda2/lib/python2.7/lib-old',
#  '/opt/anaconda2/lib/python2.7/lib-dynload',
#  '/opt/anaconda2/lib/python2.7/site-packages',
#  '/opt/anaconda2/lib/python2.7/site-packages/Sphinx-1.4.6-py2.7.egg',
#  '/opt/anaconda2/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg',
#  '/opt/anaconda2/lib/python2.7/site-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ps -ef | grep python
# Out:
# root      9520     1  0 03:35 ?        00:00:23 /opt/anaconda2/bin/python /opt/anaconda2/bin/jupyter-notebook
# root     11815  9520  0 18:29 ?        00:00:06 /opt/anaconda2/bin/python -m ipykernel -f /root/.local/share/jupyter/runtime/kernel-48877e08-ac96-47a4-94b6-1ca2759225cb.json
# root     11982  9520  0 18:44 ?        00:00:00 /opt/anaconda2/bin/python -m ipykernel -f /root/.local/share/jupyter/runtime/kernel-9c47a5f2-1356-41b7-9f6d-aae5cde74449.json
# root     12092 11815  0 19:00 pts/6    00:00:00 /bin/sh -c ps -ef | grep python
# root     12094 12092  0 19:00 pts/6    00:00:00 grep python

# %%
# !free
# Out:
#              total       used       free     shared    buffers     cached
# Mem:       1019280     876820     142460         60     100428     415732
# -/+ buffers/cache:     360660     658620
# Swap:            0          0          0
